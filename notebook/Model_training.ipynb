# %%
import pandas as pd

# %%
df=pd.read_csv('telco_cleaned.csv')

# %%
df["Churn"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Churn'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr(), cmap="coolwarm")
plt.show()

# %%
sns.boxplot(x="Churn", y="MonthlyCharges", data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %%
X_train, X_test, y_train, y_test=(train_test_split(X, y, test_size=0.2, stratify=y))

# %%
num_cols=["tenure","MonthlyCharges","TotalCharges"]
scaler=StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(class_weight="balanced")

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7412935323383084

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[749 284]
#  [ 80 294]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.80      1033
#            1       0.51      0.79      0.62       374
#
#     accuracy                           0.74      1407
#    macro avg       0.71      0.76      0.71      1407
# weighted avg       0.80      0.74      0.75      1407

# %%
y_prob = model.predict_proba(X_test)[:,1]
y_pred_new = (y_prob > 0.4).astype(int)

# %%
from sklearn.metrics import roc_auc_score
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# ROC-AUC: 0.8568133933147314

# %%
import pandas as pd

coeff = pd.DataFrame({
    "Feature": X.columns,
    "Importance": model.coef_[0]
}).sort_values(by="Importance", ascending=False)

print(coeff.head(10))
# Out:
#                            Feature  Importance
# 8                     TotalCharges    0.730476
# 10     InternetService_Fiber optic    0.512817
# 21  PaymentMethod_Electronic check    0.327613
# 6                 PaperlessBilling    0.276741
# 1                    SeniorCitizen    0.252813
# 16                 StreamingTV_Yes    0.192814
# 9                MultipleLines_Yes    0.153419
# 7                   MonthlyCharges    0.146985
# 17             StreamingMovies_Yes    0.109394
# 2                          Partner    0.008559

# %%
import pickle

pickle.dump(model, open("model.pkl", "wb"))

pickle.dump(scaler, open("scaler.pkl", "wb"))

pickle.dump(X.columns, open("columns.pkl", "wb"))
